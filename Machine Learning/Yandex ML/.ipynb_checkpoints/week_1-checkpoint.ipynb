# %%
import numpy as np
import pandas as pd
import re

data = pd.read_csv('titanic.csv', index_col = 'PassengerId')

# 1. Number of men and women
men_numb = np.sum(data['Sex'] == 'male')
women_numb = np.sum(data['Sex'] == 'female')

with open('1.txt', 'w') as f:
    f.write(' '.join(map( lambda x: str(x), [men_numb, women_numb])))

# 2. Survive percentage
sur = np.sum(data['Survived'] == 1)
total_numb = data['Survived'].shape[0]
sur_percent = float(sur) / float(total_numb) * 100

ans = '{0:.2f}'.format(sur_percent)
with open('2.txt', 'w') as f:
    f.write(ans)


# Percentage of passengers in first class
p1_class_numb = np.sum(data['Pclass'] == 1)
p1_class_percent = float(p1_class_numb) / float(total_numb) * 100

ans = '{0:.2f}'.format(p1_class_percent)
with open('3.txt', 'w') as f:
    f.write(ans)

# Mean age and median of passengers
avg_age = data['Age'].mean()
mean_age = data['Age'].median()

ans = '{0:.2f} '.format(avg_age) + str(mean_age)
with open('4.txt', 'w') as f:
    f.write(ans)

# Correlation coefficient
cor = data['SibSp'].corr(data['Parch'])
ans = '{0:.2f} '.format(cor)
with open('5.txt', 'w') as f:
    f.write(ans)

# The most popular women name
women_mask = data['Sex'] == 'female'
dfWomen = data['Name'][women_mask].copy()
a = list(dfWomen)
index = 234
print(a[index])
print(re.split(r'(Miss|Mrs|Mme|Ms)', a[index])[1])
for i in range(len(a)):
    print('{0} '.format(i) + re.split(r'(Miss|Mrs|Mme|Ms)', a[i])[0])
# Out:
# 314
# Panula, Mrs. Juha (Maria Emilia Ojala)
# Mrs
# 0 Cumings,
# 1 Heikkinen,
# 2 Futrelle,
# 3 Johnson,
# 4 Nasser,
# 5 Sandstrom,
# 6 Bonnell,
# 7 Vestrom,
# 8 Hewlett,
# 9 Vander Planke,
# 10 Masselmani,
# 11 McGowan,
# 12 Palsson,
# 13 Asplund,
# 14 O'Dwyer,
# 15 Spencer,
# 16 Glynn,
# 17 Vander Planke,
# 18 Nicola-Yarred,
# 19 Ahlin,
# 20 Turpin,
# 21 Laroche,
# 22 Devaney,
# 23 O'Driscoll,
# 24 Arnold-Franchi,
# 25 Harper,
# 26 Faunthorpe,
# 27 Rugg,
# 28 West,
# 29 Icard,
# 30 Nye,
# 31 Andersson,
# 32 Goodwin,
# 33 Dowdell,
# 34 McDermott,
# 35 Ilett,
# 36 Backstrom,
# 37 Fortune,
# 38 Doling,
# 39 Petranec,
# 40 Salkjelsvik,
# 41 Moran,
# 42 Zabour,
# 43 Jussila,
# 44 Attalah,
# 45 Andersson,
# 46 Webber,
# 47 Peter,
# 48 Robins,
# 49 Weisz,
# 50 Newsom,
# 51 Boulos,
# 52 Nysten,
# 53 Hakkarainen,
# 54 Ford,
# 55 Pears,
# 56 Gilnagh,
# 57 Watt,
# 58 Chibnall,
# 59 Skoog,
# 60 Johnson,
# 61 Isham,
# 62 Sage,
# 63 Kink-Heilmann,
# 64 O'Brien,
# 65 Pinsky,
# 66 Andersen-Jensen,
# 67 Brown,
# 68 Lurette,
# 69 Madigan,
# 70 Yrois,
# 71 Strom,
# 72 Carr,
# 73 Cameron,
# 74 Newell,
# 75 Honkanen,
# 76 Bazzani,
# 77 Lefebre,
# 78 Harris,
# 79 Asplund,
# 80 Harknett,
# 81 Collyer,
# 82 Zabour,
# 83 Murphy,
# 84 Lindahl,
# 85 Hamalainen,
# 86 Strom,
# 87 Rosblom,
# 88 Touma,
# 89 Thorne,
# 90 Cherry,
# 91 Ward,
# 92 Parrish,
# 93 Henry,
# 94 Graham,
# 95 Bissette,
# 96 Mellinger,
# 97 Healy,
# 98 Andrews,
# 99 Lindblom,
# 100 Abbott,
# 101 Connolly,
# 102 Barber,
# 103 Bishop,
# 104 Haas,
# 105 Allison,
# 106 Baxter,
# 107 Kelly,
# 108 Keane,
# 109 Fleming,
# 110 Penasco y Castellana,
# 111 Francatelli,
# 112 Hays,
# 113 Ryerson,
# 114 Lahtinen,
# 115 Nilsson,
# 116 Kantor,
# 117 Wick,
# 118 Spedden,
# 119 Slayter,
# 120 Caldwell,
# 121 Young,
# 122 Ball,
# 123 Goldsmith,
# 124 Hippach,
# 125 McCoy,
# 126 Frauenthal,
# 127 Burns,
# 128 Fortune,
# 129 Brown,
# 130 Smith,
# 131 Davison,
# 132 Bowerman,
# 133 Funk,
# 134 McGovern,
# 135 Mockler,
# 136 Barbara,
# 137 Warren,
# 138 Moussa,
# 139 Jermyn,
# 140 Aubart,
# 141 Palsson,
# 142 Meyer,
# 143 Landergren,
# 144 Bidois,
# 145 Nakid,
# 146 Holverson,
# 147 Buss,
# 148 Lehmann,
# 149 Newell,
# 150 Sandstrom,
# 151 Olsson,
# 152 Trout,
# 153 Jussila,
# 154 Oreskovic,
# 155 Lefebre,
# 156 Minahan,
# 157 Meek,
# 158 Drew,
# 159 Silven,
# 160 Van Impe,
# 161 Danbom,
# 162 Clarke,
# 163 Phillips,
# 164 Thorneycroft,
# 165 Louch,
# 166 Carter,
# 167 Ford,
# 168 Richards,
# 169 Hart,
# 170 Reynaldo,
# 171 Mellinger,
# 172 Baclini,
# 173 Kenyon,
# 174 Toomey,
# 175 Baclini,
# 176 West,
# 177 Jerwan,
# 178 Strandberg,
# 179 Hirvonen,
# 180 Turkula,
# 181 Lefebre,
# 182 Hoyt,
# 183 Eustis,
# 184 Allison,
# 185 Canavan,
# 186 O'Sullivan,
# 187 Laitinen,
# 188 Maioni,
# 189 Quick,
# 190 Rothschild,
# 191 Lemore,
# 192 Angle,
# 193 Perreault,
# 194 Hippach,
# 195 Ridsdale,
# 196 Quick,
# 197 Peter,
# 198 Cacic,
# 199 Hart,
# 200 LeRoy,
# 201 Frolicher,
# 202 Crosby,
# 203 Andersson,
# 204 Andersson,
# 205 Beane,
# 206 Ohman,
# 207 Duff Gordon, Lady. (Lucille Christiana Sutherland) ("
# 208 Taussig,
# 209 de Messemaeker,
# 210 Meanwell,
# 211 Palsson,
# 212 Appleton,
# 213 Kelly,
# 214 Garside,
# 215 Silvey,
# 216 Caram,
# 217 Christy,
# 218 Thayer,
# 219 Taussig,
# 220 Stephenson,
# 221 Bourke,
# 222 Leitch,
# 223 Jacobsohn,
# 224 Laroche,
# 225 Shutes,
# 226 Andersson,
# 227 Murphy,
# 228 Herman,
# 229 Lobb,
# 230 Becker,
# 231 Longley,
# 232 Skoog,
# 233 Davis,
# 234 Panula,
# 235 Sagesser, Mlle. Emma
# 236 Skoog,
# 237 Baclini,
# 238 Stanley,
# 239 Doling,
# 240 O'Leary,
# 241 Hegarty,
# 242 Bourke,
# 243 Taylor,
# 244 Brown,
# 245 Turja,
# 246 Goodwin,
# 247 Peters,
# 248 Madill,
# 249 Karun,
# 250 Mullens,
# 251 Astor,
# 252 Barbara,
# 253 Kelly,
# 254 Cleaver,
# 255 Mayne, Mlle. Berthe Antonine ("
# 256 Endres,
# 257 Troutt,
# 258 Harper,
# 259 Renouf,
# 260 Mannion,
# 261 Ilmakangas,
# 262 Allen,
# 263 Ford,
# 264 Ryerson,
# 265 Sinkkonen,
# 266 Wells,
# 267 Herman,
# 268 Rothes, the Countess. of (Lucy Noel Martha Dyer-Edwards)
# 269 Carter,
# 270 Hogeboom,
# 271 Mangan,
# 272 Mack,
# 273 Hocking,
# 274 Emanuel,
# 275 Robert,
# 276 Ayoub,
# 277 Dick,
# 278 Sjoblom,
# 279 Sage,
# 280 Leader, Dr. Alice (Farnham)
# 281 Osman,
# 282 Van Impe,
# 283 Collyer,
# 284 Pettersson,
# 285 Chambers,
# 286 Andersson,
# 287 Heininen,
# 288 Hays,
# 289 Moor,
# 290 Stone,
# 291 Yasbeck,
# 292 Compton,
# 293 Serepeca,
# 294 Goldenberg,
# 295 Boulos,
# 296 Lines,
# 297 Carter,
# 298 Aks,
# 299 Wick,
# 300 Baclini,
# 301 Swift,
# 302 Sage,
# 303 Bystrom,
# 304 Duran y More,
# 305 Beckwith,
# 306 Abelson,
# 307 Najib,
# 308 Potter,
# 309 Shelley,
# 310 Dahlberg,
# 311 Rice,
# 312 Graham,
# 313 Johnston,

# %%
import random as rnd
import matplotlib.pyplot as plt

list_len = 10

names = ['Bob', 'Alex', 'Dmitri', 'Andrew', 'Max']

l_names = [names[rnd.randint(0, len(names)-1)] for i in range(list_len)]
l_years = np.random.normal(2000, 20, list_len)

data = zip(l_names, l_years)

df = pd.DataFrame(data, columns = ['Names', 'Year'])
# Apply round() function to all coulmn to convert from double to int
df['Year'] = df['Year'].apply(lambda x : int(round(x)))
df['Names'] = df['Names'].apply(lambda x : x.upper())
# Add column
df['Avg diff'] = np.abs(df['Year'] - df['Year'].mean())

print(df)

n = df.groupby('Names')
n.mean().plot.bar()
plt.show()

df['Year'].plot(figsize= (10,5))
plt.show()
# Out:
#     Names  Year  Avg diff
# 0     BOB  1975      20.8
# 1     MAX  1989       6.8
# 2  ANDREW  1972      23.8
# 3  DMITRI  1979      16.8
# 4     MAX  1987       8.8
# 5     MAX  1999       3.2
# 6     BOB  2017      21.2
# 7    ALEX  1993       2.8
# 8  ANDREW  2017      21.2
# 9  DMITRI  2030      34.2

# %% [markdown]
# https://bitbucket.org/hrojas/learn-pandas
#
# read_csv()
# df.to_csv()
# df.sort_values()
# a = df.groupby() - группирует по уникальнымм значениям столбца (уже создает объект, то есть можно писать потом a.mean(), a.sum(), a.std())
# Можно просто потроить гистограмму.
# Например:
# n.mean('Names').plot.bar()
# plt.show()
# df['State'].unique() - уникальные ключи в выбранном поле
# df['State'] = df.State.apply(lambda x: x.upper())
# df.loc['12'] - выберает строку 12 в нашей таблице, то есть это как оператор []

# %%
a = ['Nasser, Mrs. Nicholas (Adele Achem)', 'Andersson, Miss. Ebba Iris Alfrida']
for i in a:
    print(re.split(r'(Miss. |Mrs. )', i)[2])
# Out:
# Nicholas (Adele Achem)
# Ebba Iris Alfrida
