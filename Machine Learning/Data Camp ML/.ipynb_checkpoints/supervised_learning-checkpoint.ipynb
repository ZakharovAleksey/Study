# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# ## Classification task. kNN.
#
# Load data from IRIS dataset.

# %%
iris = datasets.load_iris() # load_digits() for MNIST
iris.keys()
# Out:
# ['target_names', 'data', 'target', 'DESCR', 'feature_names']

# %%
X = pd.DataFrame(data=iris.data, columns=iris.feature_names)
y = iris.target

df = X.copy()
df['iris type'] = y

# %% [markdown]
# ### Explorary Data Analysis

# %%
_ = pd.plotting.scatter_matrix(
    X, c=map(lambda x: 'C{0}'.format(x + 1), y), 
    figsize=[8, 8], s=50, marker='o', alpha=0.8,
    hist_kwds = {'bins' : 10, 'color' : 'C2', 'alpha' : 0.8}
)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6, 6))
_ = sns.heatmap(df.corr(), square=True, cmap='RdYlGn', ax=ax, alpha=0.8)
plt.show()

# %% [markdown]
# Prepair train and test datasets.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=241)

# %% [markdown]
# Find optimal number of neighbors using cross validation.

# %%
n_neighb = np.arange(2, 15, 2)
scores = np.empty(n_neighb.shape[0])

cv = KFold(n_splits=5, shuffle=True, random_state=241)

for ind, cur_n in enumerate(n_neighb):
    clf_knn = KNeighborsClassifier(n_neighbors=cur_n, n_jobs=-1)
    score = np.mean(
        cross_val_score(clf_knn, X_train, y_train, cv = cv, n_jobs=-1)
    )
    scores[ind] = score

# %%
neigb_opt = n_neighb[np.argmax(scores)]
print('Optimal number of neighbors = {0}'.format(neigb_opt))

fig, ax = plt.subplots(figsize=(8, 4))

ax.plot(n_neighb, scores, color='C0', alpha=0.5, lw=5)
ax.set_xlabel('Number of neighbors')
ax.set_ylabel('Cross Validation score')

plt.show()
# Out:
# Optimal number of neighbors = 10

# %% [markdown]
# Perform prediction on test dataset.

# %%
clf_knn = KNeighborsClassifier(n_neighbors=neigb_opt, n_jobs=-1)

clf_knn = clf_knn.fit(X_train, y_train)
y_pred = clf_knn.predict(X_test)

# %% [markdown]
# Calculate different methods of prediction quality.

# %%
accuracy   = accuracy_score(y_test, y_pred)
precision  = precision_score(y_test, y_pred, average=None)
recall     = recall_score(y_test, y_pred, average=None)
f_measure  = f1_score(y_test, y_pred, average=None)

lab = ['Precision', 'Recall', 'f measure']

print('Accuracy: {:0.3f}'.format(accuracy))

for ind, cur_score in enumerate([precision, recall, f_measure]):
    print('{:}: class1 = {:0.3f}; class2 = {:0.3f}; class3 = {:0.3f}'.format(
        lab[ind], cur_score[0], cur_score[1], cur_score[2])
    )
# Out:
# Accuracy: 0.974
# Precision: class1 = 1.000; class2 = 0.941; class3 = 1.000
# Recall: class1 = 1.000; class2 = 1.000; class3 = 0.875
# f measure: class1 = 1.000; class2 = 0.970; class3 = 0.933

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# # ToDo:
#
# Items, listed below, I shoud do in this notepad (or OneNoute):
# - Write about Linear Regression
# - Plot Confusion matrix in EDA section
# - Write about density plot with sns (EDA)
# - Write and read about regularization (L1 - choose optimal features; L2 - removes muli-colliniarity).
# - Lasso / Ridge in linear regression
# - Write about sns.countplot(x='education', hue='party', data=df, palette='RdBu') for categorical features.
# - Undersampling / oversampling / examples of libraries !!!
# - AUC_ROC curves explanation -> onenoute. after lesson at DataCamp.
